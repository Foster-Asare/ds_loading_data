# %% [markdown]
# ## Importing Libraries

# %%
## loading and processing dataset

import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Loading Dataset

# %%
data = pd.read_csv("dataset/Iris_data_sample.csv")
data
# Out:
#      Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0             1           5.1           3.5           1.4           0.2
# 1             2           4.9           NaN           1.4           0.2
# 2             3           4.7           3.2           1.3           0.2
# 3             4            ??           3.1           1.5           0.2
# 4             5             5           3.6           ###           0.2
# ..          ...           ...           ...           ...           ...
# 145         146           6.7           3.0           5.2           2.3
# 146         147           6.3           2.5             5           1.9
# 147         148           6.5           3.0           5.2           2.0
# 148         149           6.2           3.4           5.4           2.3
# 149         150           5.9           3.0           5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2       Iris-setosa
# ...

# %%
data1 = pd.read_table("dataset/Iris_data_sample.txt")

data1
# Out:
#     "SepalLengthCm" "SepalWidthCm" "PetalLengthCm" "PetalWidthCm" "Species"
# 0                    1 1 5.1 3.5 1.4 0.2 "Iris-setosa"
# 1                      2 2 4.9 3 1.4 0.2 "Iris-setosa"
# 2                    3 3 4.7 3.2 1.3 0.2 "Iris-setosa"
# 3                    4 4 4.6 3.1 1.5 0.2 "Iris-setosa"
# 4                      5 5 5 3.6 1.4 0.2 "Iris-setosa"
# ..                                                 ...
# 145             146 146 6.7 3 5.2 2.3 "Iris-virginica"
# 146             147 147 6.3 2.5 5 1.9 "Iris-virginica"
# 147               148 148 6.5 3 5.2 2 "Iris-virginica"
# 148           149 149 6.2 3.4 5.4 2.3 "Iris-virginica"
# 149             150 150 5.9 3 5.1 1.8 "Iris-virginica"
#
# [150 rows x 1 columns]

# %%
## loading data in txt format with quotes, therefore use delimiter

data_iris = pd.read_table("dataset/Iris_data_sample.txt", delimiter=" ")

data_iris
# Out:
#      Unnamed: 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1             1            5.1           3.5            1.4           0.2
# 2             2            4.9           3.0            1.4           0.2
# 3             3            4.7           3.2            1.3           0.2
# 4             4            4.6           3.1            1.5           0.2
# 5             5            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 146         146            6.7           3.0            5.2           2.3
# 147         147            6.3           2.5            5.0           1.9
# 148         148            6.5           3.0            5.2           2.0
# 149         149            6.2           3.4            5.4           2.3
# 150         150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
## loading toyota csv data
data_toyota = pd.read_csv("dataset/Toyota.csv")

data_toyota
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %% [markdown]
# ## Understanding Dataset

# %%
df_iris = data_iris.copy(deep=True)

# %%
df_iris = data_iris.copy(deep=False)

# %%
df_iris
# Out:
#      Unnamed: 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1             1            5.1           3.5            1.4           0.2
# 2             2            4.9           3.0            1.4           0.2
# 3             3            4.7           3.2            1.3           0.2
# 4             4            4.6           3.1            1.5           0.2
# 5             5            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 146         146            6.7           3.0            5.2           2.3
# 147         147            6.3           2.5            5.0           1.9
# 148         148            6.5           3.0            5.2           2.0
# 149         149            6.2           3.4            5.4           2.3
# 150         150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %% [markdown]
# ## Explore and Understand Data

# %%
##Creating a deep copy of the toyota dataset
toyota_df = data_toyota.copy()

toyota_df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
##Getting Indexes of the row/ the row lables
toyota_df.index
# Out:
# RangeIndex(start=0, stop=1436, step=1)

# %%
## Get to know column names/ Get all column names
toyota_df.columns
# Out:
# Index(['Unnamed: 0', 'Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor',
#        'Automatic', 'CC', 'Doors', 'Weight'],
#       dtype='object')

# %%
## Display the items in the list
for each_item in toyota_df.columns:
    print(each_item)
# Out:
# Unnamed: 0
# Price
# Age
# KM
# FuelType
# HP
# MetColor
# Automatic
# CC
# Doors
# Weight

# %%
## Get the data typr for each columns
toyota_df.dtypes
# Out:
# Unnamed: 0      int64
# Price           int64
# Age           float64
# KM             object
# FuelType       object
# HP             object
# MetColor      float64
# Automatic       int64
# CC              int64
# Doors          object
# Weight          int64
# dtype: object

# %%
## Lets get a concise summary of our dataframe
toyota_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
## Lets get the size of the dataframe
toyota_df.size
# Out:
# 15796

# %%
## Lets get the exact of rows and column in the dataframe
print(f' total number of rows: {toyota_df.shape[0]}, Total number of colums: {toyota_df.shape[1]}')
# Out:
#  total number of rows: 1436, Total number of colums: 11

# %%
## Display the first five rows of the dataframe
toyota_df.head()
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
toyota_df.head(10)
# Out:
#    Unnamed: 0  Price   Age     KM FuelType    HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel    90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel    90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel    90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel    90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel    90       0.0          0  2000
# 5           5  12950  32.0  61000   Diesel    90       0.0          0  2000
# 6           6  16900  27.0     ??   Diesel  ????       NaN          0  2000
# 7           7  18600  30.0  75889      NaN    90       1.0          0  2000
# 8           8  21500  27.0  19700   Petrol   192       0.0          0  1800
# 9           9  12950  23.0  71138   Diesel  ????       NaN          0  1900
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170
# 5      3    1170
# ...

# %%
## Display the last 5 rows
toyota_df.tail()
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#      Doors  Weight
# 1431     3    1025
# 1432     3    1015
# 1433     3    1015
# 1434     3    1015
# 1435     5    1114

# %%
##{} , . to get sections of our data

# %% [markdown]
# ## Indexing / Slicing / selecting sections of the dataframe
# - Access a single value from a row/column pair (.at)
# - Access a single value from a row/column pair by integer positionn (.iat)
# - Access a group of rows and columns by label (s) or a boolean array. (.loc)

# %%
## Getting a single value by the row number and column name
toyota_df.at[4, 'FuelType']
# Out:
# 'Diesel'

# %%
toyota_df.at[9, 'KM']
# Out:
# '71138'

# %%
toyota_df.iat[4, 4]
# Out:
# 'Diesel'

# %%
## all the values in the FuelType column
toyota_df.loc[15:30, 'FuelType']
# Out:
# 15    Petrol
# 16    Petrol
# 17    Petrol
# 18    Petrol
# 19    Petrol
# 20    Petrol
# 21       NaN
# 22    Petrol
# 23    Petrol
# 24    Petrol
# 25    Petrol
# 26       NaN
# 27    Petrol
# 28    Petrol
# 29       NaN
# 30    Petrol
# Name: FuelType, dtype: object

# %% [markdown]
# ## Understanding Data types in Pandas
# - Numeric (int | Float)
# - Object (Categorical, object)

# %%
## Check for unique values in each column
toyota_df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %%
toyota_df.dtypes.value_counts()
# Out:
# int64      5
# object     4
# float64    2
# Name: count, dtype: int64

# %%
## Select data based on the type

toyota_df.select_dtypes(exclude=[object])
# Out:
#       Unnamed: 0  Price   Age  MetColor  Automatic    CC  Weight
# 0              0  13500  23.0       1.0          0  2000    1165
# 1              1  13750  23.0       1.0          0  2000    1165
# 2              2  13950  24.0       NaN          0  2000    1165
# 3              3  14950  26.0       0.0          0  2000    1165
# 4              4  13750  30.0       0.0          0  2000    1170
# ...          ...    ...   ...       ...        ...   ...     ...
# 1431        1431   7500   NaN       1.0          0  1300    1025
# 1432        1432  10845  72.0       0.0          0  1300    1015
# 1433        1433   8500   NaN       0.0          0  1300    1015
# 1434        1434   7250  70.0       1.0          0  1300    1015
# 1435        1435   6950  76.0       0.0          0  1600    1114
#
# [1436 rows x 7 columns]

# %%
## Select based upon including
toyota_df.select_dtypes(include=[int, float])
# Out:
#       Unnamed: 0  Price   Age  MetColor  Automatic    CC  Weight
# 0              0  13500  23.0       1.0          0  2000    1165
# 1              1  13750  23.0       1.0          0  2000    1165
# 2              2  13950  24.0       NaN          0  2000    1165
# 3              3  14950  26.0       0.0          0  2000    1165
# 4              4  13750  30.0       0.0          0  2000    1170
# ...          ...    ...   ...       ...        ...   ...     ...
# 1431        1431   7500   NaN       1.0          0  1300    1025
# 1432        1432  10845  72.0       0.0          0  1300    1015
# 1433        1433   8500   NaN       0.0          0  1300    1015
# 1434        1434   7250  70.0       1.0          0  1300    1015
# 1435        1435   6950  76.0       0.0          0  1600    1114
#
# [1436 rows x 7 columns]

# %%
## Picking each column and checking its uniqueness
## Get all the unique instatnces in price


(toyota_df['Price'].unique())
# Out:
# array([13500, 13750, 13950, 14950, 12950, 16900, 18600, 21500, 20950,
#        19950, 19600, 22500, 22000, 22750, 17950, 16750, 16950, 15950,
#        16250, 17495, 15750, 15500, 14750, 19000, 15800, 21950, 20500,
#        13250, 15250, 18950, 15999, 16500, 18750, 22250, 12995, 18450,
#        16895, 14900, 17250, 15450, 16650, 17450, 16450, 18900, 18990,
#        18500, 19450, 18800, 32500, 31000, 31275, 24950, 22950, 24990,
#        17900, 19250, 16350, 21750, 15850, 23000, 19900, 23950, 24500,
#        17200, 19500, 16868, 19750, 20750, 17650, 17795, 18245, 23750,
#        18700, 21125,  6950,  9500, 11950,  7750,  4350,  4750, 11750,
#        11900,  9950, 11495, 11250, 10500, 10450, 11500, 12500, 10950,
#        11450, 11790, 12450, 11690, 12750, 11925, 12900, 11650, 10850,
#         9940, 13450, 12495, 12000, 11480, 14990, 12850, 11700, 11895,
#        13875, 12295, 13995,  9900, 11990, 10750, 11695, 11000, 12400,
# ...

# %%
## Unique values in Age

toyota_df['Age'].unique()
# Out:
# array([23., 24., 26., 30., 32., 27., 25., 22., 31., 28., 29., nan, 20.,
#        19., 17., 11., 18., 13., 14.,  4.,  8.,  7., 16., 15., 10., 12.,
#         9.,  6.,  2.,  1., 43., 38., 40., 44., 41., 37., 39., 42., 35.,
#        34., 33., 36., 53., 51., 54., 45., 55., 48., 52., 49., 56., 50.,
#        47., 46., 58., 68., 59., 62., 65., 67., 64., 60., 61., 66., 57.,
#        63., 73., 79., 78., 74., 77., 69., 80., 76., 70., 71., 75., 72.])

# %%
## Unique values in KM

toyota_df['KM'].unique()
# Out:
# array(['46986', '72937', '41711', ..., '30964', '20544', '17016'],
#       shape=(1256,), dtype=object)

# %%
## Unique values in HP
print(np.unique(toyota_df['HP']))
# Out:
# ['107' '110' '116' '192' '69' '71' '72' '73' '86' '90' '97' '98' '????']

# %%
## Unique values in MetColor
print(np.unique(toyota_df['MetColor']))
# Out:
# [ 0.  1. nan]

# %%
## Unique values in Automatic
print(np.unique(toyota_df['Automatic']))
# Out:
# [0 1]

# %%
## Unique values in CC
print(np.unique(toyota_df['CC']))
# Out:
# [1300 1332 1398 1400 1587 1598 1600 1800 1900 1975 1995 2000]

# %%
## Unique values in Doors
print(np.unique(toyota_df['Doors']))
# Out:
# ['2' '3' '4' '5' 'five' 'four' 'three']

# %%
## Unique values in Weight
print(np.unique(toyota_df['Weight']))
# Out:
# [1000 1010 1015 1020 1025 1030 1035 1040 1045 1050 1055 1060 1065 1067
#  1070 1075 1078 1079 1080 1083 1084 1085 1090 1094 1095 1100 1103 1105
#  1109 1110 1114 1115 1119 1120 1121 1125 1130 1135 1140 1150 1155 1160
#  1165 1170 1172 1180 1185 1195 1205 1245 1255 1260 1265 1270 1275 1280
#  1320 1480 1615]

# %%
 #toyota_df.columns
for col in toyota_df.columns:
    print(f' Unique Data Instance in {col}')
    print(toyota_df[col].unique())
# Out:
#  Unique Data Instance in Unnamed: 0
# [   0    1    2 ... 1433 1434 1435]
#  Unique Data Instance in Price
# [13500 13750 13950 14950 12950 16900 18600 21500 20950 19950 19600 22500
#  22000 22750 17950 16750 16950 15950 16250 17495 15750 15500 14750 19000
#  15800 21950 20500 13250 15250 18950 15999 16500 18750 22250 12995 18450
#  16895 14900 17250 15450 16650 17450 16450 18900 18990 18500 19450 18800
#  32500 31000 31275 24950 22950 24990 17900 19250 16350 21750 15850 23000
#  19900 23950 24500 17200 19500 16868 19750 20750 17650 17795 18245 23750
#  18700 21125  6950  9500 11950  7750  4350  4750 11750 11900  9950 11495
#  11250 10500 10450 11500 12500 10950 11450 11790 12450 11690 12750 11925
#  12900 11650 10850  9940 13450 12495 12000 11480 14990 12850 11700 11895
#  13875 12295 13995  9900 11990 10750 11695 11000 12400 12200 12695 14350
#  10250  6500  6400  7000  8900  8500  8950  9250  9450  8250  4450  9000
# ...

# %%
##Lets find out all the missing values in the data
toyota_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %% [markdown]
# ### Preprocessing of data
# - Remove the 'Unnamed : 0'

# %%
toyota_df.columns
# Out:
# Index(['Unnamed: 0', 'Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor',
#        'Automatic', 'CC', 'Doors', 'Weight'],
#       dtype='object')

# %%
toyota_df.drop(columns=['Unnamed: 0'], axis=1)
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
## Lets convert the KM column to numeric
toyota_df['KM'] = pd.to_numeric(toyota_df['KM'], errors='coerce')

# %%
toyota_df.dtypes
# Out:
# Unnamed: 0      int64
# Price           int64
# Age           float64
# KM            float64
# FuelType       object
# HP             object
# MetColor      float64
# Automatic       int64
# CC              int64
# Doors          object
# Weight          int64
# dtype: object

# %%
## Convert the Doors column to numeric

# %%
toyota_df.dtypes
# Out:
# Unnamed: 0      int64
# Price           int64
# Age           float64
# KM            float64
# FuelType       object
# HP             object
# MetColor      float64
# Automatic       int64
# CC              int64
# Doors          object
# Weight          int64
# dtype: object

# %%
toyota_df
# Out:
#       Unnamed: 0  Price   Age       KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90       0.0          0
# ...          ...    ...   ...      ...      ...  ...       ...        ...
# 1431        1431   7500   NaN  20544.0   Petrol   86       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86       0.0          0
# 1433        1433   8500   NaN  17016.0   Petrol   86       0.0          0
# 1434        1434   7250  70.0      NaN      NaN   86       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110       0.0          0
#
#         CC  Doors  Weight
# 0     2000  three    1165
# ...

# %%
## Lets replace the value three with 3, four with 4 and five with 5
toyota_df['Doors'] = toyota_df['Doors'].replace('three', 3)
toyota_df['Doors'] = toyota_df['Doors'].replace('four', 4)
toyota_df['Doors'] = toyota_df['Doors'].replace('five', 5)

# %%
## Converting the Doors column to numeric
toyota_df['Doors'] = pd.to_numeric(toyota_df['Doors'], errors='coerce')

# %%
toyota_df.dtypes
# Out:
# Unnamed: 0      int64
# Price           int64
# Age           float64
# KM            float64
# FuelType       object
# HP             object
# MetColor      float64
# Automatic       int64
# CC              int64
# Doors           int64
# Weight          int64
# dtype: object

# %%
toyota_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM             15
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %% [markdown]
# ### replace missing values
# - Numeric : Mean, Mode , Median
# - Categorical : Group each cat, Highest count (Mode)
#  - Red = 10, Green = 6, Black =  3

# %%
## Col for average age
mean_age = toyota_df['Age'].mean()

# %%
## Replace nan with mean age
toyota_df['Age'] = toyota_df['Age'].fillna(mean_age)

# %%
toyota_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age             0
# KM             15
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
## Replacing missing values for KM
toyota_df['KM'] = toyota_df['KM'].fillna(toyota_df['KM'].mean())

# %%
toyota_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age             0
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
## Replace missing values for Fueltype
toyota_df['FuelType'].value_counts()
# Out:
# FuelType
# Petrol    1177
# Diesel     144
# CNG         15
# Name: count, dtype: int64

# %%
highest_count_fueltype = toyota_df['FuelType'].value_counts().index[0]

highest_count_fueltype
# Out:
# 'Petrol'

# %%
toyota_df['FuelType'] = toyota_df['FuelType'].fillna(highest_count_fueltype)

# %%
toyota_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age             0
# KM              0
# FuelType        0
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
## replace missing value for Met Color
## convert column to category type
toyota_df['MetColor'] = toyota_df['MetColor'].fillna(toyota_df['MetColor'].value_counts().index[0])

# %%
toyota_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Price         0
# Age           0
# KM            0
# FuelType      0
# HP            0
# MetColor      0
# Automatic     0
# CC            0
# Doors         0
# Weight        0
# dtype: int64

# %%
## Convert Automatic, Fuel type, Doors and MetColor to category
toyota_df['MetColor'] = toyota_df['MetColor'].astype('category')
toyota_df['Automatic'] = toyota_df['Automatic'].astype('category')
toyota_df['Doors'] = toyota_df['Doors'].astype('category')
toyota_df['FuelType'] = toyota_df['FuelType'].astype('category')

# %%
toyota_df.dtypes
# Out:
# Unnamed: 0       int64
# Price            int64
# Age            float64
# KM             float64
# FuelType      category
# HP              object
# MetColor      category
# Automatic     category
# CC               int64
# Doors         category
# Weight           int64
# dtype: object

# %%
toyota_df.to_csv('cleaned_toyota_dataset.csv', index=False)

# %%
numerical_data = toyota_df.select_dtypes(include=[int, float])

# %%
toyota_df.dtypes
# Out:
# Unnamed: 0       int64
# Price            int64
# Age            float64
# KM             float64
# FuelType      category
# HP              object
# MetColor      category
# Automatic     category
# CC               int64
# Doors         category
# Weight           int64
# dtype: object

# %%
corr_matrix = numerical_data.corr()
corr_matrix ['Price']
# Out:
# Unnamed: 0   -0.738289
# Price         1.000000
# Age          -0.845111
# KM           -0.565016
# CC            0.165067
# Weight        0.581198
# Name: Price, dtype: float64

# %% [markdown]
# ### Explorating the Data

# %%
sns.scatterplot(data=toyota_df, x='Age', y='Price')
# Out:
# <Axes: xlabel='Age', ylabel='Price'>
