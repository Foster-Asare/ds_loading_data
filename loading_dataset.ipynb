# %% [markdown]
# ## Importing Libraries

# %%
## loading and processing dataset

import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading Dataset

# %%
data = pd.read_csv("dataset/Iris_data_sample.csv")
data
# Out:
#      Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0             1           5.1           3.5           1.4           0.2
# 1             2           4.9           NaN           1.4           0.2
# 2             3           4.7           3.2           1.3           0.2
# 3             4            ??           3.1           1.5           0.2
# 4             5             5           3.6           ###           0.2
# ..          ...           ...           ...           ...           ...
# 145         146           6.7           3.0           5.2           2.3
# 146         147           6.3           2.5             5           1.9
# 147         148           6.5           3.0           5.2           2.0
# 148         149           6.2           3.4           5.4           2.3
# 149         150           5.9           3.0           5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2       Iris-setosa
# ...

# %%
data1 = pd.read_table("dataset/Iris_data_sample.txt")

data1
# Out:
#     "SepalLengthCm" "SepalWidthCm" "PetalLengthCm" "PetalWidthCm" "Species"
# 0                    1 1 5.1 3.5 1.4 0.2 "Iris-setosa"
# 1                      2 2 4.9 3 1.4 0.2 "Iris-setosa"
# 2                    3 3 4.7 3.2 1.3 0.2 "Iris-setosa"
# 3                    4 4 4.6 3.1 1.5 0.2 "Iris-setosa"
# 4                      5 5 5 3.6 1.4 0.2 "Iris-setosa"
# ..                                                 ...
# 145             146 146 6.7 3 5.2 2.3 "Iris-virginica"
# 146             147 147 6.3 2.5 5 1.9 "Iris-virginica"
# 147               148 148 6.5 3 5.2 2 "Iris-virginica"
# 148           149 149 6.2 3.4 5.4 2.3 "Iris-virginica"
# 149             150 150 5.9 3 5.1 1.8 "Iris-virginica"
#
# [150 rows x 1 columns]

# %%
## loading data in txt format with quotes, therefore use delimiter

data_iris = pd.read_table("dataset/Iris_data_sample.txt", delimiter=" ")

data_iris
# Out:
#      Unnamed: 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1             1            5.1           3.5            1.4           0.2
# 2             2            4.9           3.0            1.4           0.2
# 3             3            4.7           3.2            1.3           0.2
# 4             4            4.6           3.1            1.5           0.2
# 5             5            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 146         146            6.7           3.0            5.2           2.3
# 147         147            6.3           2.5            5.0           1.9
# 148         148            6.5           3.0            5.2           2.0
# 149         149            6.2           3.4            5.4           2.3
# 150         150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
## loading toyota csv data
data_toyota = pd.read_csv("dataset/Toyota.csv")

data_toyota
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %% [markdown]
# ## Understanding Dataset

# %%
df_iris = data_iris.copy(deep=True)

# %%
df_iris = data_iris.copy(deep=False)

# %%
df_iris
# Out:
#      Unnamed: 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1             1            5.1           3.5            1.4           0.2
# 2             2            4.9           3.0            1.4           0.2
# 3             3            4.7           3.2            1.3           0.2
# 4             4            4.6           3.1            1.5           0.2
# 5             5            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 146         146            6.7           3.0            5.2           2.3
# 147         147            6.3           2.5            5.0           1.9
# 148         148            6.5           3.0            5.2           2.0
# 149         149            6.2           3.4            5.4           2.3
# 150         150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# ...
